# %%
#!/usr/bin/env python
# coding: utf-8

# In[ ]:


from flask import Flask, render_template, request
import pickle
import numpy as np


# Construct the absolute file path to the pickle file on PythonAnywhere
pickle_file_path = "Ecommerce-Linear Regression.pkl"

# Load the machine learning model from the pickle file
with open(pickle_file_path, 'rb') as f:
    model = pickle.load(f)

model = pickle.load(open("Ecommerce-Linear Regression.pkl",'rb'))
app = Flask(__name__)

@app.route('/')
def index():
    return render_template('index.html')

@app.route('/predict',methods=['POST'])
def predict_amount_spent():
    Avg_Session_Length = float(request.form.get('Avg_Session_Length'))
    Time_on_App = float(request.form.get('Time_on_App'))
    Time_on_Website = float(request.form.get('Time_on_Website'))
    Length_of_Membership = float(request.form.get('Length_of_Membership'))

    result = model.predict(np.array([Avg_Session_Length,Time_on_App,Time_on_Website,Length_of_Membership]).reshape(1,4))

    if result < 0:
        result = str(0)
        return render_template('index.html',result=result)
    else:
        result = str(round(result[0],2))
        return render_template('index.html',result=result)

if __name__ == '__main__':
    app.run(debug=True, use_reloader=False)


# In[ ]:
# Out:
#  * Serving Flask app '__main__'
#  * Debug mode: on
# C:\Users\DELL PC\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\base.py:329: UserWarning: Trying to unpickle estimator LinearRegression from version 1.3.1 when using version 1.1.1. This might lead to breaking code or invalid results. Use at your own risk. For more info please refer to:
# https://scikit-learn.org/stable/model_persistence.html#security-maintainability-limitations
#   warnings.warn(
# WARNING: This is a development server. Do not use it in a production deployment. Use a production WSGI server instead.
#  * Running on http://127.0.0.1:5000
# Press CTRL+C to quit
# 127.0.0.1 - - [06/Jun/2024 20:52:27] "GET / HTTP/1.1" 200 -
# 127.0.0.1 - - [06/Jun/2024 20:52:27] "GET /favicon.ico HTTP/1.1" 404 -
# 127.0.0.1 - - [06/Jun/2024 20:54:52] "GET / HTTP/1.1" 200 -
# 127.0.0.1 - - [06/Jun/2024 20:55:47] "GET / HTTP/1.1" 200 -
# 127.0.0.1 - - [06/Jun/2024 21:00:24] "GET / HTTP/1.1" 200 -
# 127.0.0.1 - - [06/Jun/2024 21:03:29] "GET / HTTP/1.1" 200 -
# 127.0.0.1 - - [06/Jun/2024 21:05:14] "GET / HTTP/1.1" 200 -
# 127.0.0.1 - - [06/Jun/2024 21:05:16] "GET / HTTP/1.1" 200 -
# 127.0.0.1 - - [06/Jun/2024 21:05:24] "GET / HTTP/1.1" 200 -
# 127.0.0.1 - - [06/Jun/2024 21:05:32] "GET / HTTP/1.1" 200 -
# 127.0.0.1 - - [06/Jun/2024 21:07:12] "GET / HTTP/1.1" 200 -
# 127.0.0.1 - - [06/Jun/2024 21:08:22] "GET / HTTP/1.1" 200 -
# C:\Users\DELL PC\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# 127.0.0.1 - - [06/Jun/2024 21:08:42] "POST /predict HTTP/1.1" 200 -
# C:\Users\DELL PC\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# 127.0.0.1 - - [06/Jun/2024 21:10:18] "POST /predict HTTP/1.1" 200 -
# C:\Users\DELL PC\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# 127.0.0.1 - - [06/Jun/2024 21:12:04] "POST /predict HTTP/1.1" 200 -
# C:\Users\DELL PC\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# 127.0.0.1 - - [06/Jun/2024 21:12:09] "POST /predict HTTP/1.1" 200 -
# C:\Users\DELL PC\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# 127.0.0.1 - - [06/Jun/2024 21:12:51] "POST /predict HTTP/1.1" 200 -
# C:\Users\DELL PC\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# 127.0.0.1 - - [06/Jun/2024 21:13:58] "POST /predict HTTP/1.1" 200 -
# C:\Users\DELL PC\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# 127.0.0.1 - - [06/Jun/2024 21:26:31] "POST /predict HTTP/1.1" 200 -
# 127.0.0.1 - - [06/Jun/2024 21:26:31] "GET /image.jpg HTTP/1.1" 404 -
# C:\Users\DELL PC\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# 127.0.0.1 - - [06/Jun/2024 21:27:19] "POST /predict HTTP/1.1" 200 -
# 127.0.0.1 - - [06/Jun/2024 21:27:19] "GET /image.jpg HTTP/1.1" 404 -
# C:\Users\DELL PC\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# 127.0.0.1 - - [06/Jun/2024 21:31:47] "POST /predict HTTP/1.1" 200 -
# 127.0.0.1 - - [06/Jun/2024 21:31:47] "GET /image.jpg HTTP/1.1" 404 -
# C:\Users\DELL PC\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# 127.0.0.1 - - [06/Jun/2024 21:32:41] "POST /predict HTTP/1.1" 200 -
# 127.0.0.1 - - [06/Jun/2024 21:32:41] "GET /image.jpg HTTP/1.1" 404 -
# C:\Users\DELL PC\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# 127.0.0.1 - - [06/Jun/2024 21:38:50] "POST /predict HTTP/1.1" 200 -
# 127.0.0.1 - - [06/Jun/2024 21:38:50] "GET /static/image.jpg HTTP/1.1" 404 -
# C:\Users\DELL PC\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# 127.0.0.1 - - [06/Jun/2024 21:38:54] "POST /predict HTTP/1.1" 200 -
# 127.0.0.1 - - [06/Jun/2024 21:38:54] "GET /static/image.jpg HTTP/1.1" 404 -
# C:\Users\DELL PC\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# 127.0.0.1 - - [06/Jun/2024 21:41:54] "POST /predict HTTP/1.1" 200 -
# 127.0.0.1 - - [06/Jun/2024 21:41:54] "GET /static/image.jpg HTTP/1.1" 404 -
# C:\Users\DELL PC\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# 127.0.0.1 - - [06/Jun/2024 21:43:21] "POST /predict HTTP/1.1" 200 -
# 127.0.0.1 - - [06/Jun/2024 21:43:21] "GET /img192%20P.jpg HTTP/1.1" 404 -
# C:\Users\DELL PC\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# 127.0.0.1 - - [06/Jun/2024 21:43:31] "POST /predict HTTP/1.1" 200 -
# C:\Users\DELL PC\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# 127.0.0.1 - - [06/Jun/2024 21:46:39] "POST /predict HTTP/1.1" 200 -
# C:\Users\DELL PC\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# 127.0.0.1 - - [06/Jun/2024 21:51:01] "POST /predict HTTP/1.1" 200 -
# C:\Users\DELL PC\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# 127.0.0.1 - - [06/Jun/2024 21:51:17] "POST /predict HTTP/1.1" 200 -
# C:\Users\DELL PC\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# 127.0.0.1 - - [06/Jun/2024 21:51:30] "POST /predict HTTP/1.1" 200 -
# C:\Users\DELL PC\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# 127.0.0.1 - - [06/Jun/2024 21:51:41] "POST /predict HTTP/1.1" 200 -
# C:\Users\DELL PC\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# 127.0.0.1 - - [06/Jun/2024 21:51:49] "POST /predict HTTP/1.1" 200 -
# C:\Users\DELL PC\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# 127.0.0.1 - - [06/Jun/2024 21:52:03] "POST /predict HTTP/1.1" 200 -
# 127.0.0.1 - - [06/Jun/2024 21:58:26] "GET / HTTP/1.1" 200 -
